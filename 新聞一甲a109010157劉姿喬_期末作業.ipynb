# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010157/Computational-Thinking-and-Program-Design/blob/main/%E6%96%B0%E8%81%9E%E4%B8%80%E7%94%B2a109010157%E5%8A%89%E5%A7%BF%E5%96%AC_%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#最一開始

防疫開頭="""
哈囉，防疫期間我們來一起做運動吧
總共有四種人物可以選擇喔!
"""
print(防疫開頭)  

#選角

print("那來看看我們有提供那些選項吧~")
charc=int(input("1-最悲角色 2-動漫夯角 3-台灣天團 4-地方首長 (輸入數字)"))
if charc==1:
    sad_name=(input("你叫什麼名字...?"))
    print(f"{sad_name},一大早起來很累吧...透過運動甩去疲憊吧 咳~")
    start="""
    好討厭喔，因為疫情都要待在家裡
    待在家廢著廢著，身體不只慢慢變胖，還會不健康（QQ
    但為了身體，我們還是勉強動起來吧
    咳~ 我已經感覺好累了 但我都動起來了。你可不能偷懶阿
    """
    print(start)
    b="""
    聽說一天要運動大概30分鐘，咳~
    為了身體，我們來動吧... (好累
    """
    print(b)
    ##第一天
    monday="""
    今天又是星期一…我們來開始運動吧，咳~
    """
    print(monday)
    time1=int(input("今天運動了多久啊?(分鐘)"))
    if time1>60:
        print("我們休息一下吧，操過頭… 好累… (暈倒")
    elif time1>45:
        print("哇嗚...你運動真久，我都快要累死了")
    elif time1>30:
        print("運動真久，厲害… ")
    elif time1>15:
        print("咳~ 勉勉強強吧")
    elif time1>=0:
        print("只動一下下… 你這樣身體還好嗎?")
    ##4
    print("今天的",time1,"分鐘，這是你的運動時間")
    d="""
    希望你不會嫌棄我，明天再繼續吧
    """
    print(d)

    ##第二天
    tuesday="""
    怎麼才過兩天… 持續來運動  吧
    """
    print(tuesday)
    time2=int(input("你今天運動了多久呢?(分鐘)"))
    if time2>60:
        print("我們休息一下吧，操過頭… 好累… (暈倒")
    elif time2>45:
        print("哇嗚...你運動真久，我都快要累死了")
    elif time2>30:
        print("運動真久，厲害… ")
    elif time2>15:
        print("咳~ 勉勉強強吧")
    elif time2>=0:
        print("只動一下下… 你這樣身體還好嗎?")

    timea=int(time1+time2)
    print("今天的",time2,"分鐘，加上昨天的",time1,"分鐘，總共是",timea,"分鐘。")
    d="""
    運動連續兩天了 再加油吧，明天再見
    """
    print(d)

    ##第三天
    wednesday="""
    禮拜三了誒 為什麼一個禮拜那麼長呢? 算了，去運動 吧
    """
    print(wednesday)
    time3=int(input("今天運動的時間怎麼樣呢?(分鐘)"))
    if time3>60:
        print("我們休息一下吧，操過頭… 好累… (暈倒")
    elif time3>45:
        print("哇嗚...你運動真久，我都快要累死了")
    elif time3>30:
        print("運動真久，厲害… ")
    elif time3>15:
        print("咳~ 勉勉強強吧")
    elif time3>=0:
        print("只動一下下… 你這樣身體還好嗎?")

    timeb=int(timea+time3)
    print("今天的",time3,"分鐘，加上前幾天的",timea,"分鐘，總共是",timeb,"分鐘。")
    d="""
    為了身體好，明天再見吧
    """
    print(d)


    ##第四天
    thursday="""
    今天禮拜四 …… …… 運動啊
    """
    print(thursday)
    time4=int(input("今天運動的時間怎麼樣呢?(分鐘)"))
    if time4>60:
        print("我們休息一下吧，操過頭… 好累… (暈倒")
    elif time4>45:
        print("哇嗚...你運動真久，我都快要累死了")
    elif time4>30:
        print("運動真久，厲害… ")
    elif time4>15:
        print("咳~ 勉勉強強吧")
    elif time4>=0:
        print("只動一下下… 你這樣身體還好嗎?")

    timec=int(timeb+time4)
    print("今天的",time4,"分鐘，加上前幾天的",timeb,"分鐘，總共是",timec,"分鐘。")
    d="""
    快要放假了，我們努力一下吧
    """
    print(d)

    ##第五天
    friday="""
    到禮拜五了 終於要放假了… 但還是要動起來
    """
    print(friday)
    time5=int(input("今天運動的時間怎麼樣呢?(分鐘)"))
    if time5>60:
        print("我們休息一下吧，操過頭… 好累… (暈倒")
    elif time5>45:
        print("哇嗚...你運動真久，我都快要累死了")
    elif time5>30:
        print("運動真久，厲害… ")
    elif time5>15:
        print("咳~ 勉勉強強吧")
    elif time5>=0:
        print("只動一下下… 你這樣身體還好嗎?")

    timed=int(timec+time5)
    print("今天的",time5,"分鐘，加上前幾天的",timec,"分鐘，總共是",timed,"分鐘。")
    d="""
    明天終於放假拉~但是為了身體，還是得持續運動啊...
    """
    print(d)

    ##總結
    print("來計算一下這五天的運動時間總共多少吧")
    print("所以你總共運動了",timed,"分鐘。")
    if timed<150:
        h="""
        身體會當機的，當機要怎麼辦!
        感覺要努力動起來了，好緊張。
        是我讓你不夠有動力嗎?真難過...
        """
        print(h)
    elif timed>150:
        g="""
        有點被你的汗水激勵到了，下次繼續保持阿
        下次我會盡量不那麼喪的...吧
        """
        print(g)

    ##互動
    print("另外，雖然沒什麼自信 但我，咳~有點想分享…一些東西，你會想看關於運動或飲食的知識嗎?")
    inter=int(input("1-運動 2-飲食 (輸入數字)"))
    if inter==1:
        excerise="""
        《美國臨床營養期刊》研究指出，一個晚上沒睡，可能使你隔天新陳代謝速度減緩20％。
        身體一整夜無法休息將使新陳代謝活動疲乏，而無法有效燃燒卡路里。
        不僅如此，睡眠不足會讓別人覺得你不美、不健康，醫師建議一天最好睡滿八小時。
        如果還是常打瞌睡，可試著健走20分鐘，讓你更有精神！
        """
        print(excerise)
    elif inter==2:
        food="""
        不要忘記吃早餐，通過每天早晨所吃下的早餐，
        才能提供足夠的能量與營養面對一天工作的挑戰；
        建議早餐可以選擇健康的全麥穀物、牛奶、蛋、粥和「較清淡」的食物，
        以及一些新鮮水果和足夠的水。
        """
        print(food)

    ########動漫夯角########
elif charc==2:

    ##一些設定
    print("恭喜入學東京都立咒術高級專門學校")
    print("你的導師將會是五條悟")
    print("作為與此世結緣的依據")
    name=input("接下來請告訴我你的名字:")
    print("請好好享受這短暫的時光",name)
    ## Day1 (1)防疫要來運動的開場白，今天是星期一......
    print("早安∽清醒了嗎?五條老師有重要的事情要宣布哦∽")
    print("嗯嗯很好，認真聽哦，接下來的一個月受到疫情影響，非常不幸的只能待在家裡啦∽")
    print("什麼?真的假的?總而言之為了不被感染然後不明不白地死去當然是待在家裡安全啊，放心放心，great teacher Gojo已經想好應急措施了哦?")
    print("那就是——居宅內訓練!!")
    print("在家防疫和上課的同時還可以順便鍛鍊身體呦")
    print("嗯…訓練什麼…")
    print("……")
    print("......")
    print("這樣好了!有什麼目標都跟老師講吧!老師會好好幫",name,"紀錄哦!")
    print("怎麼樣~很棒吧~人家可是給了你很自由的空間捏~")
    print("麼就從今天開始吧，提醒一下今天是禮拜一哦")
    print("讓我們開始吧!為期五天一輪的訓練!")
    ##(2)：定下達成的目標(ex.每天30分鐘)
    print("好的!五條老師在哦!")
    print("決定好目標了?很好很好，那就現在告訴我吧，我會嚴格監督你的哦!")
    min=int(input("那麼每天訓練時間要幾分鐘?"))
    total=min*5
    print("OK!確認每天",min,"分鐘!")
    ##3)成果
    day1=int(input("忙碌一天辛苦啦!那麼今天運動多久了呢?"))
    if day1<=15:
        print("蛤?才這麼點時間啊…喂喂——加油點加油點，你的潛力不只這麼點吧?")
        print("好好拿出實力來啊，老師都這麼認真陪你記錄了，那怕是看在這點也給我好好努力啊!")
    elif day1<=30:
        print("嗯…馬馬虎虎吧。")
        print("加油加油!")
    elif day1<=45:
        print("很好!就是這樣!拿出幹勁來吧少年!")
        print("老師很期待你的表現哦!")
    elif day1<60:
        print("good job!")
        print("看來即使待在家裡也沒有偷懶呢!")
        print("就保持這股幹勁突破極限吧!!")
    else:
        print("做得很好哦，不過適當休息也很重要哦")

    print("那麼第一天的成績是",day1,"分鐘")
    print("明天也要好好加油哦")
    ## Day2
    print("早安!第二天的訓練要開始了!")
    day2=int(input("忙碌一天辛苦啦!那麼今天運動多久了呢?"))
    if day2<=15:
        print("蛤?才這麼點時間啊…喂喂——加油點加油點，你的潛力不只這麼點吧?")
        print("好好拿出實力來啊，老師都這麼認真陪你記錄了，那怕是看在這點也給我好好努力啊!")
    elif day2<=30:
        print("嗯…還行")
        print("再更努力一點吧!")
    elif day2<=45:
        print("很好!就是這樣!拿出幹勁來吧少年!")
        print("老師很期待你的表現哦!")
    elif day2<60:
        print("嗚哦!good job!")
        print("看來即使待在家裡也沒有偷懶呢!")
        print("就保持這股幹勁突破極限吧!!")
    else:
        print("做得很好哦，不要忘記休息啊")
        print("適當休息有利於接下來的訓練哦")

    print("第二天的成果是",day2,"分鐘~")
    print("目前為止已經累積訓練了",day1+day2,"分鐘了，要繼續努力哦")
    ## Day3
    print("第三天開始啦!感覺應該還行吧?如果有好好努力的話最後結算有驚喜哦~")
    day3=int(input("忙碌一天辛苦啦!那麼今天運動多久了呢?"))
    if day3<=15:
        print("蛤?才這麼點時間啊…喂喂——加油點加油點，你的潛力不只這麼點吧?")
        print("好好拿出實力來啊，老師都這麼認真陪你記錄了，那怕是看在這點也給我好好努力啊!")
    elif day3<=30:
        print("嗯…馬馬虎虎叭")
        print("不可以偷懶哦?繼續加油吧!")
    elif day3<=45:
        print("很好!就是這樣!拿出幹勁來吧少年!")
        print("老師很期待你的表現哦!")
    elif day3<60:
        print("嗚哦!good job!")
        print("看來即使待在家裡也沒有偷懶呢!")
        print("就保持這股幹勁突破極限吧!!")
    else:
        print("是不是有句話叫「休息是為了更長遠的路」")
        print("累過頭的話接下來的訓練可是會提不起幹勁的")

    print("第三天的成績是——",day3,"分鐘!")
    print("目前為止已經訓練",day1+day2+day3,"分鐘了呢，不錯嘛")
    ## Day4
    print("第4天~~快結束了加油加油!")
    day4=int(input("忙碌一天辛苦啦!那麼今天運動多久了呢?"))
    if day4<=15:
        print("蛤?才這麼點時間啊…喂喂——加油點加油點，你的潛力不只這麼點吧?")
        print("好好拿出實力來啊，老師都這麼認真陪你記錄了，那怕是看在這點也給我好好努力啊!")
    elif day4<=30:
        print("嗯…馬馬虎虎叭")
        print("不可以偷懶哦?繼續加油吧!")
    elif day4<=45:
        print("很好!就是這樣!拿出幹勁來吧少年!")
        print("老師很期待你的表現哦!")
    elif day4<60:
        print("嗚哦!good job!")
        print("看來即使待在家裡也沒有偷懶呢!")
        print("就保持這股幹勁突破極限吧!!GOGO!!!")
    else:
        print(name,"好認真啊....")
        print("老師也要加油了呢，不然明天試著祓除那些老橘子好了?")
        print("好啦，老師是開玩笑的")

    print("第四天你訓練了",day4,"分鐘哦")
    print("到今天已經訓練了",day1+day2+day3+day4,"分鐘啦")
    print("不錯嘛!繼續保持哦等疫情過了可是有大把咒靈等著你呢:)")
    ## Day5
    print("今天是最後一天啦，雖然是最後了但是也不能鬆懈哦")
    day5=int(input("忙碌一天辛苦啦!那麼今天運動多久了呢?"))
    if day5<=15:
        print("蛤?才這麼點時間啊…喂喂——加油點加油點，你的潛力不只這麼點吧?")
        print("唔?最後一天想偷懶一下?")
    elif day5<=30:
        print("嗯…馬馬虎虎叭")
        print("咒靈可不會管你想不像偷懶，下禮拜要好好訓練哦")
    elif day5<=45:
        print("很好!就是這樣!拿出幹勁來吧少年!")
        print("老師很期待你的表現哦!")
    elif day5<60:
        print("嗚哦!good job!")
        print("看來即使待在家裡也沒有偷懶呢!")
        print("就保持這股幹勁突破極限吧!!GOGO!!!")
    else:
        print("沒想到",name,"居然可以撐這麼久啊…")
        print("沒有啦剛剛是在開玩笑呢，別生氣啦~~")
        print(name,"做得很好哦，老師果然沒有看錯。")
        print("稍微放鬆一下吧，不用把自己逼得這麼緊沒關係的")
        print("畢竟還有我在嘛!我可是最強的哦!")

    t2=day1+day2+day3+day4+day5
    print("今天的成績是",day5,"分鐘")
    print("這個禮拜已經累計",t2,"分鐘了呢")
    print(name,"很努力哦")
    ## 總結
    print("結算時間到~!")
    print("鏘鏘~這邊是你到今天為止的成績哦!")
    print("總共是",t2,"分鐘")
    if t2<total:
        print("嗯……")
        print("好像比原訂的目標少呢…")
        print("是遇到了什麼問題嗎?")
        print("老師可是不想自己的學生在祓除咒靈的時候死掉啊",name,"🥺🥺")
        print("下禮拜也要繼續加油哦?")
    else:
        print("哈哈哈，甚好甚好")
        print("這禮拜的目標有好好達成呢")
        print("不愧是我的學生——啊哈哈neta三日月宗近被發現了呢")
        print("不管怎麼說，有努力朝著目標邁進就是一種成就呢")
        print("不論是作為咒術師也好普通人也好，每個人總會找到屬於自己的目標")
        print("如果認定了它的意義就義無反顧地走下去吧")
        print("每個選擇都是有意義的")
        print("下禮拜也要一起加油哦!!老師和同學們都相信",name,"一定會變強的!")
    ## 小驚喜
    print("好啦~不管成果如何這個禮拜的訓練都已經結束啦")
    print("你對老師說的小驚喜還有印象吧?")
    print("小驚喜是乖孩子的獎勵三選一哦")
    print("期待吧!老師平常可是很忙的，要好好把握機會哦")
    x=int(input("1:誇獎 2體術加強 3:甜點，哪一個呢?"))
    if x==1:
        A="""
        只要誇獎就好嗎?真是容易滿足
        好乖好乖~做得很好呢，你的努力老師都有看在眼裡
        記得不要因為感染病毒這種原因隨便死掉哦
        老師等著你們成長到可以與我並肩的程度呢
        """
        print(A)
    if x==2:
        B="""
        真上進
        沒錯!要變強就是要多練習!
        實戰練習也很爽啊可惜你沒辦法出門
        週末老師給你露兩手吧
        """
        print(B)
    if x==3:
        C="""
        不錯!有眼光!老師最近找到了一家新開的甜品店，他們的招牌還蠻好吃的
        怎麼樣?同意的話老師馬上就叫伊地知送過來!啊?不想麻煩伊地知先生?那麼我就親自過去取吧。
        不用擔心我會感染，我可是有無下限隔絕病毒的
        至少理論上可以，沒有什麼是我這個最強是不出來的啦
        好好期待吧!吃完甜品之後也要繼續加油哦!
        努力度過防疫期間吧!
        """
        print(C)

    ########台灣天團########
elif charc==3:
    ##第一天
    name=(input("你叫什麼名字?"))
    print(f"{name},早安!")
    a="""
    疫情來得太快，那一年我們望著星空，有那麼多的燦爛的夢，上次見面已經是半年前了，
    為了可以在今年底的跨年演唱會相遇，年過四十但是還要運動吧！今天是禮拜一，邀請你和我們一同宅在家運動，，
    我們知道潮落之後一定有潮起，一起度過難關。
    """  
    print(a)
    b="""
    每天三十分鐘讓雙腳去騰空，讓我們去感受。動動手腳，記得不要逗陣尬車，
    想要讓阿花跟阿嬌愛上你，就靠疫情這段艱困的時間好好鍛練自己！
    """
    print(b)
    ##3
    c="""
    開始吧!
    人生最好時光是和你運動一場，如果說了後悔，一切也不能倒退喔。
    """
    print(c)
    time1=int(input("今天運動了多久呢?(分鐘)"))
    if time1>60:
        print("謝謝你的倔強，堅持對你來說，就是以剛克剛，還是要記得休息喔！")
    elif time1>45:
        print("我相信，秒秒的瞬間，都會成為永恆啊！做得好。")
    elif time1>30:
        print("好厲害，但是……再繼續下去大叔們就要回家了（喂～ ")
    elif time1>15:
        print("別想，別怕，別後退，你快做到了！")
    elif time1>0:
        print("我和你，都約好了，要一起運動的，沉重都給我、微笑給你，這樣不公平吧。")
    ##4
    print("今天的",time1,"分鐘，這是你得來不易的成績")
    d="""
    Everything will be alright，Tomorrow will be fine，
    太陽依然燦爛，地球繼續轉，明天持續和我們一起健身吧。
    """
    print(d)

    ##第二天
    print(f"{name},第二天早安!")
    time2=int(input("今天運動了多久呢?(分鐘)"))
    if time2>60:
        print("謝謝你的倔強，堅持對你來說，就是以剛克剛，還是要記得休息喔！")
    elif time2>45:
        print("我相信，秒秒的瞬間，都會成為永恆啊！做得好。")
    elif time2>30:
        print("好厲害，但是……再繼續下去大叔們就要回家了（喂～ ")
    elif time2>15:
        print("別想，別怕，別後退，你快做到了！")
    elif time2>0:
        print("我和你，都約好了，要一起運動的，沉重都給我、微笑給你，這樣不公平吧。")

    timea=int(time1+time2)
    print("今天的",time2,"分鐘，這是你得來不易的成績，加上昨天的",time1,"分鐘，總共是",timea,"分鐘。")
    d="""
    Everything will be alright，Tomorrow will be fine，
    太陽依然燦爛，地球繼續轉，明天持續和我們一起健身吧。
    """
    print(d)

    ##第三天
    print(f"{name},第三天早安!")
    time3=int(input("今天運動了多久呢?(分鐘)"))
    if time3>60:
        print("謝謝你的倔強，堅持對你來說，就是以剛克剛，還是要記得休息喔！")
    elif time3>45:
        print("我相信，秒秒的瞬間，都會成為永恆啊！做得好。")
    elif time3>30:
        print("好厲害，但是……再繼續下去大叔們就要回家了（喂～ ")
    elif time3>15:
        print("別想，別怕，別後退，你快做到了！")
    elif time3>0:
        print("我和你，都約好了，要一起運動的，沉重都給我、微笑給你，這樣不公平吧。")

    timeb=int(timea+time3)
    print("今天的",time3,"分鐘，這是你得來不易的成績，加上前幾天的",timea,"分鐘，總共是",timeb,"分鐘。")
    d="""
    Everything will be alright，Tomorrow will be fine，
    太陽依然燦爛，地球繼續轉，明天持續和我們一起健身吧。
    """
    print(d)

    ##獎勵互動
    print("為了鼓勵你繼續前進，不要停下腳步，你有想聽聽哪首歌嗎，我們可以跟你說說他的故事，就選擇那首你不太熟悉歌曲好嗎？")
    s=int(input("1-笑忘歌，2-好好，3-如煙(輸入數字)"))
    if s==1:
        x="""
        你也經歷過學生時期吧，我們幾個大叔相遇的那個青春，有很多青澀的時刻，初戀、分手，當彼此的垃圾車。
        未來有一天，不，或者就是現在，我們都處在一個極度焦躁、忙碌又空虛，兩極化的生活中，
        我們回頭望那些記憶中的朋友，以及那個平凡又快樂的人，相信你也知道那是一直在心中，年輕的自己吧。
        「我和你 都約好了 要再唱這首笑忘歌 這一生志願只要平凡快樂 誰說這樣不偉大呢」
        """
        print("x")
    elif s==2:
        z="""
        就像是，我們的音樂能和你的相遇是真是太好了，就是一種剛好。
        有時候幸福，當然也會有遺憾的瞬間，我們一起把握好那個剛好，在回憶的風景中、你緊握的雙手中，好好地照顧自己。
        「我們都要把自己照顧好 好到遺憾無法打擾 好好的生活 好好的變老 好好假裝我 已經把你忘掉」
        """
        print(z)
    elif s==3:
        y="""
        這是我第一次在歌曲中不重覆歌詞，你覺得人的生與死是什麼模樣，會想些什麼，我不知道，但我把它寫了出來。
        那位要抵達詩篇句點的老人，從七歲開始回想，曾經抓住的那隻蟬；
        還有十七歲，不能永遠，但永遠純潔的愛情，和蒼老的臉龐形成對比，願把遺憾和眷戀化成最後一滴淚。
        「有誰能聽見　我不要告別 我坐在床前　看著指尖　已經如煙」
        """
        print(y)

    ##第四天
    print(f"{name},第四天早安!")
    time4=int(input("今天運動了多久呢?(分鐘)"))
    if time4>60:
        print("謝謝你的倔強，堅持對你來說，就是以剛克剛，還是要記得休息喔！")
    elif time4>45:
        print("我相信，秒秒的瞬間，都會成為永恆啊！做得好。")
    elif time4>30:
        print("好厲害，但是……再繼續下去大叔們就要回家了（喂～ ")
    elif time4>15:
        print("別想，別怕，別後退，你快做到了！")
    elif time4>0:
        print("我和你，都約好了，要一起運動的，沉重都給我、微笑給你，這樣不公平吧。")

    timec=int(timeb+time4)
    print("今天的",time4,"分鐘，這是你得來不易的成績，加上前幾天的",timeb,"分鐘，總共是",timec,"分鐘。")
    d="""
    Everything will be alright，Tomorrow will be fine，
    太陽依然燦爛，地球繼續轉，明天持續和我們一起健身吧。
    """
    print(d)

    ##第五天
    print(f"{name},第五天早安!")
    time5=int(input("今天運動了多久呢?(分鐘)"))
    if time5>60:
        print("謝謝你的倔強，堅持對你來說，就是以剛克剛，還是要記得休息喔！")
    elif time5>45:
        print("我相信，秒秒的瞬間，都會成為永恆啊！做得好。")
    elif time5>30:
        print("好厲害，但是……再繼續下去大叔們就要回家了（喂～ ")
    elif time5>15:
        print("別想，別怕，別後退，你快做到了！")
    elif time5>0:
        print("我和你，都約好了，要一起運動的，沉重都給我、微笑給你，這樣不公平吧。")

    timed=int(timec+time5)
    print("今天的",time5,"分鐘，這是你得來不易的成績，加上前幾天的",timec,"分鐘，總共是",timed,"分鐘。")
    d="""
    Everything will be alright，Tomorrow will be fine，
    太陽依然燦爛，地球繼續轉，明天持續和我們一起健身吧。
    """
    print(d)

    ##總結
    print("勇敢的五天旅程，不知道你收穫了多少，來總結一下吧。")
    if timed<150:
        h="""
        運動成效好像……不太及格呢，但這是我的溫柔，讓你自由。
        好啦，如果你還有意願，感覺我們可以一起做到更多事情對吧，希望你會喜歡我們和音樂這一周的陪伴，
        很開心你願意參與，日後等我們一聲下令以後，記得要想起呼吸你的自由。
        """
        print(h)
    elif timed>150:
        g="""
        我都快追不上你的速度了欸，真的很厲害，為自己鼓掌吧。
        趕快去告訴大家你不是頭腦空空，也不是一隻米蟲，下周再一起奮鬥，為了健康的生活品質，
        運動是件平凡的事，但當你笑得像個孩子，每個平凡小事，都能變成永恆故事。
        """
        print(g)
        
    ########地方首長########
elif charc==4:
    ##開頭
    name=(input("你叫什麼名字?"))
    print(f"{name},一天剛開始你好啊!")
    start="""
    疫情依然嚴峻，大家一樣 ，盡量留在家、
    沒事不要出門、外出要戴口罩、不要在外面吃東西，
    但是為了身體健康，大仍要記在家做運動，不要新冠肺炎沒找上你，卻讓其他病痛找上門。
    """  
    print(start)
    b="""
    每天至少運動30分鐘強身健體
    """
    print(b)
    ##第一天
    monday="""
    開始運動吧
    """
    print(monday)
    time1=int(input("今天運動多久了?(分鐘)"))
    if time1>60:
        print("ok今天可以先到這邊了")
    elif time1>45:
        print("看起來今天狀態很好")
    elif time1>30:
        print("不錯，繼續保持")
    elif time1>15:
        print("這個齁~離目標不遠了")
    elif time1>=0:
        print("才動沒兩下，繼續")
    ##4
    print("今天的",time1,"分鐘，這是你的運動時間")
    d="""
    防疫不間斷，運動也一樣!
    """
    print(d)

    ##第二天
    tuesday="""
    開始運動吧
    """
    print(tuesday)
    time2=int(input("你今天運動多久了?(分鐘)"))
    if time2>60:
        print("ok今天可以先到這邊了")
    elif time2>45:
        print("看起來今天狀態很好")
    elif time2>30:
        print("不錯，繼續保持")
    elif time2>15:
        print("這個齁~離目標不遠了")
    elif time2>=0:
        print("才動沒兩下，繼續")

    timea=int(time1+time2)
    print("今天的",time2,"分鐘，加上昨天的",time1,"分鐘，總共是",timea,"分鐘。")
    d="""
    防疫不間斷，運動也一樣!
    """
    print(d)

    ##第三天
    wednesday="""
    開始運動吧
    """
    print(wednesday)
    time3=int(input("你今天運動多久了?(分鐘)"))
    if time3>60:
        print("ok今天可以先到這邊了")
    elif time3>45:
        print("看起來今天狀態很好")
    elif time3>30:
        print("不錯，繼續保持")
    elif time3>15:
        print("這個齁~離目標不遠了")
    elif time3>=0:
        print("才動沒兩下，繼續")

    timeb=int(timea+time3)
    print("今天的",time3,"分鐘，加上前幾天的",timea,"分鐘，總共是",timeb,"分鐘。")
    d="""
    防疫不間斷，運動也一樣!
    """
    print(d)


    ##第四天
    thursday="""
    開始運動吧
    """
    print(thursday)
    time4=int(input("你今天運動多久了?(分鐘)"))
    if time4>60:
        print("ok今天可以先到這邊了")
    elif time4>45:
        print("看起來今天狀態很好")
    elif time4>30:
        print("不錯，繼續保持")
    elif time4>15:
        print("這個齁~離目標不遠了")
    elif time4>=0:
        print("才動沒兩下，繼續")

    timec=int(timeb+time4)
    print("今天的",time4,"分鐘，加上前幾天的",timeb,"分鐘，總共是",timec,"分鐘。")
    d="""
    防疫不間斷，運動也一樣!
    """
    print(d)

    ##第五天
    friday="""
    開始運動吧
    """
    print(friday)
    time5=int(input("你今天運動多久了?(分鐘)"))
    if time5>60:
        print("ok今天可以先到這邊了")
    elif time5>45:
        print("看起來今天狀態很好")
    elif time5>30:
        print("這個齁~離目標不遠了")
    elif time5>15:
        print("這個齁~離目標不遠了")
    elif time5>=0:
        print("才動沒兩下，繼續")

    timed=int(timec+time5)
    print("今天的",time5,"分鐘，加上前幾天的",timec,"分鐘，總共是",timed,"分鐘。")
    d="""
    防疫不間斷，運動也一樣!假日也一樣不能鬆懈!
    """
    print(d)

    ##總結
    print("總結一下這五天的運動量吧")
    print("所以你總共運動了",timed,"分鐘。")
    if timed<150:
        h="""
        明天開始由不得你，下週我要看到至少運動總結150
        """
        print(h)
    elif timed>150:
        g="""
        保持下去，我認為你會有健康的身體狀況
        """
        print(g)

    ##互動
    print("為了鼓勵你，我不坐在辦公室看數據，我直接去一線與你同在!")
    inter=int(input("1-阿伯帶你在家騎飛輪，2-阿伯帶你爬樓梯，鍛鍊心肺功能!，(輸入數字)"))
    if inter==1:
        飛輪="""
        雖然現在不能一日北高騎自行車，但阿伯帶你在家騎飛輪，效果一樣好
        """
        print(飛輪)
    elif inter==2:
        爬樓梯="""
        每天多爬樓梯10分鐘就能降低BMI值，爬樓梯三大好處:1,增加柔軟度 2,提高身體代謝率 3,消除下半身肥胖
        """
        print(爬樓梯)
# Out:
# 哈囉，防疫期間我們來一起做運動吧
# 總共有四種人物可以選擇喔!
#
# 那來看看我們有提供那些選項吧~
# 1-最悲角色 2-動漫夯角 3-台灣天團 4-地方首長 (輸入數字)1
# 你叫什麼名字...?ㄉ
# ㄉ,一大早起來很累吧...透過運動甩去疲憊吧 咳~
#
#     好討厭喔，因為疫情都要待在家裡
#     待在家廢著廢著，身體不只慢慢變胖，還會不健康（QQ
#     但為了身體，我們還是勉強動起來吧
#     咳~ 我已經感覺好累了 但我都動起來了。你可不能偷懶阿
#
#
#     聽說一天要運動大概30分鐘，咳~
#     為了身體，我們來動吧... (好累
#
#
#     今天又是星期一…我們來開始運動吧，咳~
#
# 今天運動了多久啊?(分鐘)30
# 咳~ 勉勉強強吧
# 今天的 30 分鐘，這是你的運動時間
#
#     希望你不會嫌棄我，明天再繼續吧
#
#
#     怎麼才過兩天… 持續來運動  吧
#
# 你今天運動了多久呢?(分鐘)50
# 哇嗚...你運動真久，我都快要累死了
# 今天的 50 分鐘，加上昨天的 30 分鐘，總共是 80 分鐘。
#
#     運動連續兩天了 再加油吧，明天再見
#
#
#     禮拜三了誒 為什麼一個禮拜那麼長呢? 算了，去運動 吧
#
# 今天運動的時間怎麼樣呢?(分鐘)10
# 只動一下下… 你這樣身體還好嗎?
# 今天的 10 分鐘，加上前幾天的 80 分鐘，總共是 90 分鐘。
#
#     為了身體好，明天再見吧
#
#
#     今天禮拜四 …… …… 運動啊
#
# 今天運動的時間怎麼樣呢?(分鐘)50
# 哇嗚...你運動真久，我都快要累死了
# 今天的 50 分鐘，加上前幾天的 90 分鐘，總共是 140 分鐘。
#
#     快要放假了，我們努力一下吧
#
#
#     到禮拜五了 終於要放假了… 但還是要動起來
#
# 今天運動的時間怎麼樣呢?(分鐘)90
# 我們休息一下吧，操過頭… 好累… (暈倒
# 今天的 90 分鐘，加上前幾天的 140 分鐘，總共是 230 分鐘。
#
#     明天終於放假拉~但是為了身體，還是得持續運動啊...
#
# 來計算一下這五天的運動時間總共多少吧
# 所以你總共運動了 230 分鐘。
#
# ...

# %% [markdown]
# A109010022 楊曼伶(組長)
# A109010046 林雨蓁(組員)
# A109010070 藍誼軒(組員)
# A109010157 劉姿喬(組員)
